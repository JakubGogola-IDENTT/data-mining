# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
from statsmodels.formula.api import ols

# %% [markdown]
# # Exercise 11

# %%
auto_df = pd.read_csv('./data/Auto.csv')

# %%
auto_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
auto_df = auto_df[auto_df['horsepower'] != '?']
auto_df = auto_df.astype({
    'horsepower': float
})

# %% [markdown]
# # Year variable
#
# ## I model
#
# Let's use `year` as continuous variable.

# %%
model_1 = ols(formula='mpg ~ C(year)', data=auto_df).fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.430
# Model:                            OLS   Adj. R-squared:                  0.412
# Method:                 Least Squares   F-statistic:                     23.80
# Date:                Wed, 13 Jan 2021   Prob (F-statistic):           1.99e-39
# Time:                        15:05:41   Log-Likelihood:                -1251.1
# No. Observations:                 392   AIC:                             2528.
# Df Residuals:                     379   BIC:                             2580.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Model II
#
# Let's use `year` as categorical variable.

# %%
model_2 = ols(formula='mpg ~ year', data=auto_df).fit()
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     198.3
# Date:                Wed, 13 Jan 2021   Prob (F-statistic):           1.08e-36
# Time:                        15:05:41   Log-Likelihood:                -1280.6
# No. Observations:                 392   AIC:                             2565.
# Df Residuals:                     390   BIC:                             2573.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -70.0117      6.645    -10.536      0.000     -83.076     -56.947
# ...

# %% [markdown]
# ## Q&A
#
# ### Which model is better?
# The second one which treats year as categorical variable.
#
# ### What if there were more than 13 values for variable `year`?
# In the case where variable is continuous - nothing will change. In the case where variable is categorical - there'll be more parameters to train
#
# ### Which of those two models is easier to train?
# Continuous model because it has less parameters to train.
